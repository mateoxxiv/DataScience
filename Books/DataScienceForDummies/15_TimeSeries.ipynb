# %% [markdown]
# # Time Series

# %% [markdown]
# Is a collection of data over the time.
#
# The goal of analysing this kind of data set is to predcit future event based on past observartional data

# %% [markdown]
# ## Time series trends

# %%
# Code time series trends
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load the image (replace 'your_image.jpg' with the path to your image)
img = mpimg.imread('./Images/trends.png')

# Display the image using Matplotlib
plt.imshow(img)

# Optionally, add a title
plt.title('Time series trends')

# Optionally, hide the axes ticks
plt.axis('off')

# Show the image
plt.show()

# %% [markdown]
# ## Stationary time series

# %% [markdown]
# - Are dataset that repeat patterns over the time.
#
# - When we got a non stationary time series, it means it has an unprediuctable cycle.
#
# - Non stacionary time series can´t be forecasted, they must be transformed to a stationary one to movr on in the analysis.
