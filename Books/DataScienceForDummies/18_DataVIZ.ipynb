# %% [markdown]
# # **Data VIZ**

# %% [markdown]
# ## Types of data vix based on the audience

# %% [markdown]
# 1. **Data story telling for desition makers:** data visualizations for a less technical-minded audience, perhaps in order to help members of this audience make better- informed business decisions. The purpose of this type of visualization is to tell your audience the story behind the data. In data storytelling, the audience depends on you to make sense of the data behind the visualization and then turn useful insights into visual stories that they can understand.

# %% [markdown]
# 2. **Data showcasing for analyst:** data showcasing techniques, your goal should be to display a lot of contextual information that supports audience members in making their own interpretations.

# %% [markdown]
# 3. **Data art for activist:** designing for this audience, you want your data visualization to make a point! You can assume that typical audience members aren’t overly analytical.

# %% [markdown]
# ## Get to know your audience

# %% [markdown]
# a. Get a paper.
#
# b. Think about an imaginary member (brenda) of the aundience
#
#  - Form a picture of Brendas average day
#     - what Brenda does when gets out the bed
#     - what Brenda does during the lunh hour
#     - what Brendas place looks like
#     - what would Brenda does as data viz

# %% [markdown]
# c. Make yourself the following question:
#
# - Where does Brenda work? What does she do for a living?
# - What kind of technical education or experience, if any, does she have?
# - How old is Brenda? Is she married? Does she have children? What does she look like? Where does she live?
# - What social, political, caused-based, or professional issues are important to Brenda? What does she think of herself?
# - What problems and issues does Brenda have to deal with every day?
# - How does your data visualization help solve Brenda’s work problems or her family problems? How does it improve her self-esteem?
# - Through what avenue will you present the visualization to Brenda — for example, over the Internet or in a staff meeting?
# - What does Brenda need to be able to do with your data visualization?

# %% [markdown]
# ## Define the purpose

# %% [markdown]
# - Are you attempting to get consumers to feel a certain way about themselves or the world around them?
# -  Are you trying to make a statement?
# -  Are you seeking to influence organizational decision makers to make good business decisions?

# %% [markdown]
# ## Choose the best type of viz

# %% [markdown]
# - If you’re designing for organizational decision makers, you’ll most likely use **data storytelling** to directly tell your audience what their data means with respect to their line of business.
#
# - If you’re designing for a social justice organization or a political campaign, **data art** can best make a dramatic and effective statement with your data.
#
# - If you’re designing for engineers, scientists, or statisticians, stick with data showcasing so that these analytical types have plenty of room to figure things out on their own.

# %% [markdown]
# ## Picking the Most Appropriate Design Style

# %% [markdown]
# ### **Inducing a calculating, exacting response**

# %% [markdown]
# - Bar charts
# - Scatterplot
# - Line chart

# %% [markdown]
# - Traditional colors
# - Elegant look and feel.
