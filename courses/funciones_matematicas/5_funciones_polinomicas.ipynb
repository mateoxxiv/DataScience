# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Forma

# %% [markdown]
# $$P(x) = a_nx^n + a_{n-1}x^{n-1} + ... + a_{2}x^{2} + ax + a$$

# %% [markdown]
# # Código

# %%
# En este ejemplo ponemos

N = 100
x = np.linspace(-10,10,N)

def f(x):
    return (2*x**7) - (x**4) + (3*x**2) + 4

plt.plot(x, f(x))
plt.grid()
plt.show()
