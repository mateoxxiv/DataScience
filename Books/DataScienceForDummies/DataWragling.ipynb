# %% [markdown]
# # Data Wragling

# %% [markdown]
# Is the process and procedures that are use to clean and convert data fron its raw format and structure to another, in order to get accurate data form for tools ans scripts
