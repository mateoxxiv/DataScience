# %% [markdown]
# ## Importar libreria

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import ssl
import urllib.request

# Desactivar verificación de certificados SSL
ssl._create_default_https_context = ssl._create_unverified_context

# %% [markdown]
# ## Importar base de datos

# %%
df = sns.load_dataset('penguins')

# %%
p_df = (
    df
    .dropna()
    .copy()
)

# %% [markdown]
# ## Recomendaicones para contruir un mejor grafico de puntos

# %% [markdown]
# 1. Modificar la transparencia de los puntos
# 2. A travez de histograma

# %%
sns.scatterplot(
    data=p_df,
    x='bill_length_mm',
    y='bill_depth_mm',
    alpha=1/2,
    hue='species'
)
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.displot(
    data=p_df,
    x='bill_length_mm',
    y='bill_depth_mm',
    hue='species',
    rug=True
)

# %%
sns.displot(
    data=p_df,
    x='bill_length_mm',
    y='bill_depth_mm',
    hue='species',
    rug=True,
    kind='kde'
)

# %%
sns.jointplot(
    data=p_df,
    x='bill_length_mm',
    y='bill_depth_mm',
    hue='species'
)
