# %% [markdown]
# ## Importar libreria

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
import empiricaldist
import ssl
import urllib.request

# Desactivar verificación de certificados SSL
ssl._create_default_https_context = ssl._create_unverified_context

# %% [markdown]
# ## Importar base de datos

# %%
df = sns.load_dataset('penguins')

# %%
p_df = (
    df
    .dropna()
    .copy()
)

# %% [markdown]
# ## Funciones de densidad de probabilidad

# %%
sns.kdeplot(
    data=p_df,
    x='flipper_length_mm',
    bw_method=0.1)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Density'>

# %%
p_stats = p_df.body_mass_g.describe()

# %%
xs = np.linspace(p_stats['min'], p_stats['max'])
ys = stats.norm(p_stats['mean'], p_stats['std']).cdf(xs)

# %%
empiricaldist.Cdf.from_seq(p_df.body_mass_g).plot()
plt.plot(xs, ys)

# %%
xs = np.linspace(p_stats['min'], p_stats['max'])
ys = stats.norm(p_stats['mean'], p_stats['std']).pdf(xs)
plt.plot(xs, ys)
sns.kdeplot(
    data=p_df,
    x='body_mass_g',
    )
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Density'>
