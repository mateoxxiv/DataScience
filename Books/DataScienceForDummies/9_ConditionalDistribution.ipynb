# %% [markdown]
# # Conditional distribution (NAIVE BAYES)

# %% [markdown]
# It predicts the likelihood that an event will occur, given evidence defined in your data features.

# %% [markdown]
# ## Types

# %% [markdown]
# ### Multi nominal NB:

# %% [markdown]
# -  Use this version if your variables (categorical or continuous) describe discrete frequency counts.
#
# - This version of Naïve Bayes assumes a multinomial distribution, as is often the case with text data.

# %% [markdown]
# ### Bernouilli NB

# %% [markdown]
# - We have binary features.
#
# - It classifies text data.
#
# - If you want to use BernoulliNB to make predictions from continuous variables, that will work, but you first need to sub-divide them into discrete interval groupings

# %% [markdown]
# ### Gaussian NB

# %% [markdown]
# - We have all predictive features normally distributed.
#
# - It can be a good choice if your data contains both positive and negative values
