# %% [markdown]
# # Algorithms based on its functionality

# %% [markdown]
# ## Regression algorithm

# %% [markdown]
# - Model relationships between features in the dataset

# %% [markdown]
# ## Association rule learning algorithm

# %% [markdown]
# - Rule based set of methods
#
# - Usefull to discover association between features of a dataset

# %% [markdown]
# ## Instace based algoritm

# %% [markdown]
# - We have observations to classify new observation based on its similarity

# %% [markdown]
# ## Regularization algorithm

# %% [markdown]
# - Avoid overfiting
#
# - Intoduce added information in the model

# %% [markdown]
# ## Naive Bayes

# %% [markdown]
# - Predict the likelihood of an event occuring.
#
# - Based on the evidence inn our data

# %% [markdown]
# ## Decision tree

# %% [markdown]
# - Asistente para la toma de desiciones
#
# - Ayudar a medir las posible consecuencia de una desición en especifico

# %% [markdown]
# ## Clustering algorithms

# %% [markdown]
# - Uncover subgroups in a unlabaled dataset

# %% [markdown]
# ## Dimension reduction

# %% [markdown]
# - Remove from our data set redundant information, noise and outliers

# %% [markdown]
# ## Neuronal network

# %% [markdown]
# - Mimics how the brain solve problems
#
# - It uses layers of intercomunicated neronal units as a mean by wich to learn.
#
# - it units is call neutron that follows a process:
#
# 1. Recieve one or more inputs
#
# 2. Weigths the inputs
#
# 3. Adds inputs on a processor layer
#
# 4. Based on an activation function outputs a result

# %% [markdown]
# ## Deep learing

# %% [markdown]
# - Traditional neuronal network but used in successive layers

# %% [markdown]
# ## Ensemble algorthm

# %% [markdown]
# -  Ensemble algorithms to combine machine learning approaches to achieve results that are better than would be available from any single machine learning method on its own.
